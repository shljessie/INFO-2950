# %%
import pandas as pd 
import numpy as np

# %%
stations_geoid = pd.read_csv('citibike_stations_geoid.csv')
stations_geoid = stations_geoid.set_index('geoid').drop('Unnamed: 0',axis=1)

# %%
race_and_income = pd.read_csv('../nyc_census_tracts/race_and_income_data.csv')
race_and_income = race_and_income.set_index('geoid')

# %%
combined_table = stations_geoid.join(race_and_income,how='inner')

# %%
combined_table.head()
# Out:
#                  id                             name        lat        lon  \
# geoid
# 36047000100   407.0             Henry St & Poplar St  40.700469 -73.991454
# 36047000100   216.0  Columbia Heights & Cranberry St  40.700379 -73.995481
# 36047000100  3790.0            Henry St & Middagh St  40.700300 -73.991581
# 36047000301   406.0           Hicks St & Montague St  40.695128 -73.995951
# 36047000301  3180.0    Brooklyn Bridge Park - Pier 2  40.698780 -73.997120
#
#                   first        last   rides 2012 median income  \
# geoid
# 36047000100  2013-06-01  2019-05-31   46995              88705
# 36047000100  2013-06-01  2019-07-31   43550              88705
# 36047000100  2019-05-16  2019-07-31    4034              88705
# 36047000301  2013-06-01  2019-07-31  102765             119859
# 36047000301  2015-07-01  2018-09-30   36326             119859
#
#             2012 median income margin of error  2012 race: total households  \
# geoid
# 36047000100                              15140                         4623
# 36047000100                              15140                         4623
# 36047000100                              15140                         4623
# 36047000301                              28848                         4513
# 36047000301                              28848                         4513
#
#              ...  2016 race: 2 or more races  2017 median income  \
# geoid        ...
# 36047000100  ...                         181               88238
# 36047000100  ...                         181               88238
# 36047000100  ...                         181               88238
# 36047000301  ...                         269              130063
# 36047000301  ...                         269              130063
#
#              2017 median income margin of error  2017 race: total households  \
# geoid
# 36047000100                               10981                         4116
# 36047000100                               10981                         4116
# 36047000100                               10981                         4116
# 36047000301                               23922                         4340
# 36047000301                               23922                         4340
#
#              2017 race: total households margin of error  2017 race: White  \
# geoid
# 36047000100                                          366              2878
# 36047000100                                          366              2878
# 36047000100                                          366              2878
# 36047000301                                          480              3615
# 36047000301                                          480              3615
#
#             2017 race: Black 2017 race: Asian  2017 race: Other  \
# geoid
# 36047000100              369              419               272
# 36047000100              369              419               272
# 36047000100              369              419               272
# 36047000301              121              244               106
# 36047000301              121              244               106
#
#              2017 race: 2 or more races
# geoid
# 36047000100                         178
# 36047000100                         178
# 36047000100                         178
# 36047000301                         254
# 36047000301                         254
#
# [5 rows x 61 columns]
