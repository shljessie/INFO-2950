# %% [markdown]
# ## Citibike Trips by Neighborhood,Borough, and CountyCode

# %% [markdown]
# Here we drop the unesscessary columns in the data

# %%
import pandas as pd 
import numpy as np

# %%
# read csv
trips= pd.read_csv('../../../tripneigh.csv')

# %%
trips.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            starttime             stoptime  \
# 0           0             0  2017-01-01 00:00:21  2017-01-01 00:11:41
# 1           0             0  2017-01-01 00:00:21  2017-01-01 00:11:41
# 2           0             0  2017-01-01 00:00:21  2017-01-01 00:11:41
# 3           0             0  2017-01-01 00:00:21  2017-01-01 00:11:41
# 4           1             0  2017-01-01 00:00:21  2017-01-01 00:11:41
#
#             start station name             end station name    usertype  \
# 0  W 82 St & Central Park West  Central Park West & W 72 St  Subscriber
# 1  W 82 St & Central Park West  Central Park West & W 72 St  Subscriber
# 2  W 82 St & Central Park West  Central Park West & W 72 St  Subscriber
# 3  W 82 St & Central Park West  Central Park West & W 72 St  Subscriber
# 4  W 82 St & Central Park West  Central Park West & W 72 St  Subscriber
#
#    birth year  gender  start_station_geoid  ...  start_borough  \
# ...

# %%
# Dropping columns we're not going to use
trips = trips.drop(['Neighborhood Tabulation Area (NTA)','PUMA','Borough', 'index'], axis = 1)

# %%
trips.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            starttime             stoptime  \
# 0           0             0  2017-01-01 00:00:21  2017-01-01 00:11:41
# 1           0             0  2017-01-01 00:00:21  2017-01-01 00:11:41
# 2           0             0  2017-01-01 00:00:21  2017-01-01 00:11:41
# 3           0             0  2017-01-01 00:00:21  2017-01-01 00:11:41
# 4           1             0  2017-01-01 00:00:21  2017-01-01 00:11:41
#
#             start station name             end station name    usertype  \
# 0  W 82 St & Central Park West  Central Park West & W 72 St  Subscriber
# 1  W 82 St & Central Park West  Central Park West & W 72 St  Subscriber
# 2  W 82 St & Central Park West  Central Park West & W 72 St  Subscriber
# 3  W 82 St & Central Park West  Central Park West & W 72 St  Subscriber
# 4  W 82 St & Central Park West  Central Park West & W 72 St  Subscriber
#
#    birth year  gender  start_station_geoid  end_station_geoid  tripminutes  \
# ...

# %%
trips.to_csv('./trip_neigh.csv')
