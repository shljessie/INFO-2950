# %% [markdown]
# # Project Phase IV :  Citibike Project Final Draft
#
#
# This project aims to answer the question **How is citibike representing NYC demographics? (in 2017)**.
#
# This notebook contains the **Draft of the Final Project**
#
# #### Team Members
# - Seonghee Lee (sl994)
# - Nicholas Rahardja (nmr73)
# - Chelsea Choi (cc2583)
#
# #### Team Github
# - https://github.com/shljessie/citibike-nyc
#
# #### Team Raw Data Google Drive
# - https://drive.google.com/drive/folders/197_d1BwPHXmVuyKA6I7UEyEw4Nqo8dAk
#
#
#
# <br/>
#
# _______________

# %% [markdown]
# ## Contents of this Notebook
#
# 1. Introduction
# 2. Data Description
# 3. Pre Registration Statement
# 4. Data Analysis
# 5. Evaluation of Significance
# (till wellness day - 5days think of storyline, how to knit )
#
#
# 6. (after 26th) Interpretation and Conclusion
# 7. Limitations
# 8. Source Code
# 9. Acknowledgement
# 10. Appendix
# 11. Questions for Reviewers
#
#
# submission 28th

# %% [markdown]
# <br/>
#
# _______________
#
# # 1) Introduction
#
# 1. Context of Work
# 2. Research Question
# 3. Main Findings
# 4. Summary of Results
#
# What is the context of the work? What research question are you trying to answer? What are your main findings? Include a brief summary of your results.

# %% [markdown]
# #### 1. Context of Work
#
# Bike Sharing comes with many benefits such as providing free or affordable access to bicycles for short-distance trips. By doing so in an urban area, this reduces congestion, noise, and air pollution.
#
# However **whether or not these bike sharing systems are truly accessible for all is questionable.** Since the accessibility of these bike sharing systems depend heavily on where the stations are located, it is very likely that where you live becomes the deciding factor in whether or not you will be able to use these bikes.
#
# In coming up with our research question, we looked at many research papers on bike sharing system equity.
# For example, a [study done by Portland State University](https://trec.pdx.edu/research/project/884) suggests that significant portions of the population are underrepresented among bike share users, including people of color, along with lower-income, female, older adults and less-educated groups. An [article in 2017](https://usa.streetsblog.org/2017/07/05/whats-keeping-people-from-using-bike-share-new-study-breaks-it-down-by-race-and-income/) finds that this may be due to the fact that these low-income communities and people of color view traffic risk, high prices, and the potential for crime and harassment as the biggest barriers to bicycling and using bike-share in their neighborhoods. There has also been [data visualization research at MIT](https://aberke.github.io/income-race-bikes/) about how bikes are being distributed in NYC throughout the years in accordance to race&income.
#
# In this project, **we look into how citibike stations are distributed in NYC** and how that relates to the following factors: 1) race&income and  2) citibike usage. Are there more stations in areas of higher usage regardless of race and income? Does race and income seem to have an unignorable correlation with how citibike stations are being distributed? How much of these factors play into the distribution of citibike? How might citibike station distribution be improved? These are the questions we will ask and attempt to answer throughout this project.
#
# Through gaining insight on how citibike stations are distributed in NYC, we will attempt to gain insight into what NYC can do to improve the distribution of citibike to reflect the race/income and usage demographics.
#
# #### 2. Research Question
#
# ##### **How is citibike representing NYC demographics? (in 2017)**.
#
# #### 3. Project Design + Limitations
#
# We are specificially looking at **NYC citibike trip data in 2017 as a sample** of the representation of NYC bike stations around New York. We chose New York City's citibike system since New York City is an area where there are widely varying levels of income. We chose 2017 for two reasons,    1) NYC's race and income data was avaiable for the years 2013 -2018 and 2) 2017 was a year when many new stations of citibike where added to represent its overall usage.
# We decided that 2017 would be a fair representation of how citibike stations were distributed throughout NYC.
#
# **We chose geoid as a standard to view**
#
#
#
# #### 4. Main Findings
#
#
#
#
# #### 5. Summary of Results

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# _______________
#
# # 2) Data Description
#
# For this project we used 3 types of data
# 1. Citibike Trip Data
# 2. Citibike Station Data
# 3. NYC Race and Income Data

# %% [markdown]
# ### Data 1 : Citibike Trip Data
#
# ##### 1. What are the observations (rows) and the attributes (columns)?
#
# [Original Data]
#
# - Trip Duration (seconds)
# - Start Time and Date
# - Stop Time and Date
# - Start Station Name
# - End Station Name
# - Station ID
# - Station Lat/Long
# - Bike ID
# - User Type (Customer = 24-hour pass or 3-day pass user; Subscriber = Annual Member)
# - Gender (Zero=unknown; 1=male; 2=female)
# - Year of Birth
#
# [Cleaned Data]
#
# - Start Time and Date (datetime)
# - Stop Time and Date (datetime)
# - Start Station Name
# - End Station Name
# - User Type (Subscriber Only)
# - Gender (Zero=unknown; 1=male; 2=female)
# - Year of Birth
# - Trip Minutes
#
# ##### 2. Why was this dataset created?
#
# This dataset was created to help developers, engineers, statisticians, artists, academics and the local public to explore the usage of citi bike around New York City. Insights from these findings would help citibike officials find answers to questions like where citibike users ride, how far they go,and what stations are the most popular.  It is an open dataset on the public bike sharing system of New York City. It is open to the public to help people find insights about this system.
#
# ##### 3. Who funded the creation of the dataset?
#
# This citibike data was funded by citibike in New York. Lyft is the operator of the Citi Bike program in New York City and Jersey City. The raw dataset was collected from this source https://www.citibikenyc.com/system-data
#
# ##### 4.What processes might have influenced what data was observed and recorded and what was not?
#
# Trips that may have been taken by staff who are managing citibike throughout the city are not good representations of citibikes trips by users only. Bikes may have been relocated overnight so that the distribution of bikes around the city are evenly distributed. Also bikes that may have been broken may lead to a loss of data.  Also citibike usage trip data is not a complete representation of all bike rider data in New York.
#
# ##### 5. If people are involved, were they aware of the data collection and if so, what purpose did they expect the data to be used for?
#
# In signing up for using citibike, these users are allowing for citibike to take data of their usage.
# Citibike releases information about the user’s ride and trip duration  including their start station, usertype(Subscriber, one time user), gender, and year of birth. Citibike plans on using this data to understand citi bike users and the overall trend of citi bike users in new york city. Though many citibike users might not have been aware of this, they could have assumed that the data was collected to understand the citibike users for business related reasons.
#
# ##### 6. Where can your raw source data be found, if applicable? Provide a link to the raw data (hosted in a Cornell Google Drive or Cornell Box).
#
# https://drive.google.com/drive/folders/11YUr4yiiFKCNlN2MnGPGpCeXyrq92A0Z?usp=sharing

# %% [markdown]
# ### Data 2 : Citibike Stations Data
#
# ##### 1. What are the observations (rows) and the attributes (columns)?
#
# Each row in this data set corresponds to a unique Citi Bike station in NYC.
# The following is the meaning of each column in this data set:
# - Station_id: integer that uniquely identifies a station
# - Station_name: name of the station
# - Lat: latitude of the station
# - Long: longitude of the station
# - First_trip: Date of the first trip ever taken from the station
# - Last_trip: Data of the last trip taken from the station (at the time this data was downloaded)
# - Rides: total number of rides taken from the station
# - Geoid: geographical identifier for the NYC census tract that the station is located in
#
#
# ##### 2. Why was this dataset created?
#
# The base dataset for this table came from the same source as the Citbike trip data set described above. However, more processing was done to this data to obtain this station dataset by a team of MIT researchers who were trying to map out the locations of Citi Bike stations in NYC for their research purposes.
#
# ##### 3. Who funded the creation of the dataset?
#
# This table uses as its base table the Cibike trip data set that was funded by citibike in New York. However, the processing that was done to this raw citi bike data was done by MIT researchers, so it can be assumed that MIT indirectly funded the creation of this Citibike trip data set. MIT Media Lab research: https://github.com/aberke/income-race-bikes/tree/master/data/nyc-bike
#
#
# ##### 4.What processes might have influenced what data was observed and recorded and what was not?
#
# To get the station data to the current form, we first used an API to obtain the geoid (unique census tract identification number) from the longitude and latitude of each Citibike station. This data was then added as the ‘Geoid’ column in the data set. Next since our project focuses on 2017, I removed all stations that had its first trip after 2017 since they are not relevant to our analysis. Lastly, I renamed a few columns to make their names more intuitive. Such as renaming ‘id’ to ‘station_id’ and ‘name’ to ‘station_name’.
#
# ##### 5. If people are involved, were they aware of the data collection and if so, what purpose did they expect the data to be used for?
#
# Since this data set is derived from the citi bike trips dataset, citi bike users were made aware that citibike would be tracking their usage data, when users signed up for the application.
#
# The expected usage of this data is the same as for the Citi Bike trip data above.
#
#
# ##### 6. Where can your raw source data be found, if applicable? Provide a link to the raw data (hosted in a Cornell Google Drive or Cornell Box).
#
# https://drive.google.com/file/d/1pATvzg-PTpPvs_8x5pKIs_jqlbKrWyat/view?usp=sharing

# %% [markdown]
# ### Data 3 : Race and Income Data in 2017
# ##### 1. What are the observations (rows) and the attributes (columns)?
# Each row in this data set corresponds to a different census tract in NYC. A census tract is a geographical area, defined by the US government when they collect their census data.
# The following are the columns in this table:
# Geoid
# 2017 median income
# 2017 median income margin of error
# 2017 race : total households
# 2017 race : total households margin of error
# 2017 race: white
# 2017 race: black
# 2017 race : asian
# 2017 race : other
# 2017 race : 2 or more races
#
# ##### 2. Why was this dataset created?
# This dataset was created in order to study the census tract data along with the associated race and income in that tract from 2017. This was done by extracting the household median income and household race from the American Community Survey.
#
# ##### 3. Who funded the creation of the dataset?
# This data was created and funded by the United States Census bureau. The creation of this dataset was funded by the MIT Media Lab. This data was created and funded by the United States Census bureau. ACS: https://data.census.gov/cedsci/The creation of this dataset was funded by the MIT Media Lab. MIT Media Lab : https://github.com/aberke/income-race-bikes/blob/master/data/ny/race_and_income_data.csv.
#
# ##### 4. What processes might have influenced what data was observed and recorded and what was not?
# The American Community Survey’s data collection process is performed by randomly selecting 3.5 million addresses to reply to the survey in order to represent the entire population. Because this survey is limited to those with addresses, there may be households and individuals who are not recorded in the census. For example, the homeless population is difficult to track and therefore could influence the data as well.
#
# ##### 5. What preprocessing was done, and how did the data come to be in the form that you are using?
# Because the original data from the American Community Survey was downloaded as a shapefile, the data had to be extracted and transformed into a dataframe. After extracting the race, income, and renaming the columns, the data set was created.
#
# Next, rows where the median income was not a numeric integer were dropped except for rows that contain the value ‘$250,000+’ as their median income which were changed to ‘250,000’ so that they can be treated as numeric values. Next only the 2017, income and race columns were selected since our project focuses on 2017.

# %% [markdown]
# ##### 6. If people are involved, were they aware of the data collection and if so, what purpose did they expect the data to be used for?
# The individuals contacted were aware of the data collection. In the constitution, it states that a census must be taken every 10 years. People likely understand the main purpose of the census as determining where federal and state funding should be spent. Moreover, their data is protected from being shared and used by any other government agency.
#
# ##### 7. Where can your raw source data be found, if applicable? Provide a link to the raw data (hosted in a Cornell Google Drive or Cornell Box).
# https://drive.google.com/file/d/1obfrrDul07XDXEvyK6kf-N66_2K5-g88/view?usp=sharing

# %% [markdown]
# ## 3) Preregistration Statement

# %% [markdown]
# #### Two analyses
#
# 1. What is the relationship between usage and number of stations? (Trips vs Stations)
#     - compute usage by geoid and stations by geoid.
#     - see how citibike usage & number of stations differ between geoid.
#     - look at the overall population in a geoid and normalize
#     - Thinking of computiung linear regression to see of the number of stations correlate with the usage(this might change depending on what we find in the data)
#     - compare this to overall population.
#     - choose a few geoid's of interest to look further into
#
# 2. How is station placement by geoid representing NYC race & income demographics? (Stations vs Race/Income)
#       - After question 1, looking at geoid ares of interest, we could look in to race & income demographics of those areas?
#       - Thinking of trying out multiple linear regression with different geoids, race, and income factors included. (this might change depending on what we find in the data)

# %% [markdown]
# ## 4) Data Analysis
#
# How accessible is citibike in NYC (2017)?
#
# to answer this, we look at
#
# How is citibike representing NYC demographics? (analysis wise, seems like a more solid argument.)
#
# proposed two research questions
#
# - What is the relationship between usage and number of stations? (Trips vs Stations)
# - How is station placement by geoid representing NYC race & income demographics? (Stations vs Race/Income)
#
# In this project, **we look into how citibike stations are distributed in NYC** and how that relates to the following factors: 1) race&income and  2) citibike usage. Are there more stations in areas of higher usage regardless of race and income? Does race and income seem to have an unignorable correlation with how citibike stations are being distributed? How much of these factors play into the distribution of citibike? How might citibike station distribution be improved? These are the questions we will ask and attempt to answer throughout this project.
#
#
#
# **Basically What we are doing**
#
# "Looking at Station Distribution in NYC for each Geoid and the characteristics(race/income + trips) of that Geoid"

# %% [markdown]
# #### Team planning Storyline
#
# 1) Originally we wanted to know does more stations in a geoid lead to more trips? No!
#
# 2) So what else could be predicting more trips? So we now want to look into wether the race and income of a geoid can predict the number of trips?
#
# 3) Now that we know the relationship between trips and race, then we can look into the relationship between the number of stations in each geoid and race.
#
#
# "How is citibike representing NYC demographics? (in 2017)"
# 1. Understanding distribution of citibike
# - Trips by Geoid
# - Stations by Geoid
# - Race+ Income by Geoid
# - Grouping… dataframe
#
# 2. The relationship between each other
# - Trips vs Stations (seonghee)
# - Trips vs Race/income (nicholas)
# - Stations vs Race/income (chelsea)
#
# 3. Evaluation of Significance
# - 9pm KST Tuesday
# - What is the relationship between usage and number of stations? (Trips vs Stations)
# - How is station placement by geoid representing NYC race & income demographics? (Stations vs Race/Income)

# %% [markdown]
# ### 1. Understanding Distribution of Citibike Around NYC

# %% [markdown]
# Our research question is "How is citibike representing NYC demographics? (in 2017)"
#
# The first step that we find crucial in answering our research question is understanding how citibike trips, stations , and race+income are distributed around NYC by each geodistrict.
# After we figure out how the citibike trips and stations are distributed around NYC, we will be able find abnormalities or patterns with in the distrubution that we can take a closer look at.
#
# ##### Steps for Grouping by Geoid
#
# Here we attempted to look at geoid 's which are measure ments stated by NYC census.
# We did not need to do more for grouping race+income by geoid because that was already in our dataset.
# **We specifically chose to look at geoid's as the standard of grouping because?**
#
#
# So the first initial steps that i will go through are
#
# 1. Grouping trips by Geoid
# 2. Grouping stations by Geoid

# %%
trip = pd.read_csv('../../Desktop/citibike-nyc/data_exploration/clean_trip_data.csv')

# %%
stations = pd.read_csv('../../Desktop/citibike-nyc/data_cleaning/citbike_stations/citibike_stations_geoid_final.csv')
ri = pd.read_csv('../../Desktop/citibike-nyc/data_cleaning/race_and_income/race_and_income_final.csv')

# %% [markdown]
# ### 1. Group Trips by Geoid

# %% [markdown]
# ##### Issues
#
# - start station end station divide

# %%
trip.head()
# Out:
#    Unnamed: 0            starttime             stoptime  \
# 0           0  2017-01-01 00:00:21  2017-01-01 00:11:41
# 1           1  2017-01-01 00:00:45  2017-01-01 00:22:08
# 2           6  2017-01-01 00:05:00  2017-01-01 00:14:20
# 3           7  2017-01-01 00:05:37  2017-01-01 00:19:24
# 4           8  2017-01-01 00:05:47  2017-01-01 00:10:02
#
#             start station name             end station name    usertype  \
# 0  W 82 St & Central Park West  Central Park West & W 72 St  Subscriber
# 1       Cooper Square & E 7 St           Broadway & W 32 St  Subscriber
# 2           Broadway & W 60 St              9 Ave & W 45 St  Subscriber
# 3           Broadway & W 37 St           E 10 St & Avenue A  Subscriber
# 4             York St & Jay St   Carlton Ave & Flushing Ave  Subscriber
#
#    birth year  gender  start_station_geoid  end_station_geoid  tripminutes
# 0      1965.0       2         3.606102e+10       3.606101e+10           11
# 1      1987.0       2         3.606100e+10       3.606101e+10           21
# 2      1973.0       1         3.606101e+10       3.606101e+10            9
# 3      1977.0       2         3.606101e+10       3.606100e+10           13
# 4      1989.0       1         3.604700e+10       3.604702e+10            4

# %% [markdown]
# As you can see here, the trips have start stations and end stations. In the data cleaning process, we linked unique geoids to the start and end stations. **Now we will count the number of trips taken at each unique geoid.**

# %% [markdown]
# ### Start Stations

# %%
# group by start stations and count number of trips
trips_start_df = trip.groupby(['start_station_geoid']).size().reset_index(name = 'Number of Trips')
trips_start_df = trips_start_df.sort_values('Number of Trips', ascending=False)
trips_start_df.head()
# Out:
#      start_station_geoid  Number of Trips
# 209         3.606101e+10           269945
# 269         3.606101e+10           257733
# 227         3.606101e+10           230264
# 242         3.606101e+10           228497
# 191         3.606101e+10           203787

# %%
trips_start_df = trips_start_df.rename(columns={'start_station_geoid': 'geoid'})
trips_start_df.head()
# Out:
#             geoid  Number of Trips
# 209  3.606101e+10           269945
# 269  3.606101e+10           257733
# 227  3.606101e+10           230264
# 242  3.606101e+10           228497
# 191  3.606101e+10           203787

# %%
len(trips_start_df)
# Out:
# 382

# %%
trips_start_df['geoid'].nunique()
# Out:
# 382

# %% [markdown]
# Here we grouped the trips by the start station geoid and found the number of trips taken at each of the unique start stations in 2017.

# %% [markdown]
# We will plot a histogram to get a better idea of how the trips are distributed by geoid.

# %%
plt.hist(trips_start_df['Number of Trips'], bins=100)
plt.title(" Start Station Number of Trips ")
plt.show()

# %% [markdown]
# As you can see from the graph above, you can observe a very uneven distribution of start stations trips taken by geoid

# %% [markdown]
# ### End Stations

# %%
#group by end stations and count number of trips
trips_end_df = trip.groupby(['end_station_geoid']).size().reset_index(name = 'Number of Trips')
trips_end_df = trips_end_df.sort_values('Number of Trips', ascending=False)
trips_end_df.head()
# Out:
#      end_station_geoid  Number of Trips
# 209       3.606101e+10           264950
# 227       3.606101e+10           236628
# 269       3.606101e+10           236408
# 242       3.606101e+10           226033
# 191       3.606101e+10           208123

# %%
# rename column
# trips_end_df['geoid']=trips_end_df[]
trips_end_df = trips_end_df.rename(columns={'end_station_geoid': 'geoid'})
trips_end_df.head()
# Out:
#             geoid  Number of Trips
# 209  3.606101e+10           264950
# 227  3.606101e+10           236628
# 269  3.606101e+10           236408
# 242  3.606101e+10           226033
# 191  3.606101e+10           208123

# %%
len(trips_end_df)
# Out:
# 382

# %%
trips_end_df['geoid'].nunique()
# Out:
# 382

# %% [markdown]
# Here we grouped the trips by the start station geoid and found the number of trips taken at each of the unique start stations in 2017.

# %% [markdown]
# We will plot a histogram to get a better idea of how the trips are distributed by geoid.

# %%
plt.hist(trips_start_df['Number of Trips'], bins=100)
plt.title(" End Station Number of Trips ")
plt.show()

# %% [markdown]
# As you can see from the graph above, you can observe a very uneven distribution of start stations trips taken by geoid

# %% [markdown]
# - How to compare how much start and end stations align with each other? Is the highest start station the highest end station?
# - Normalization by Population

# %%
ri.head()
# Out:
#          geoid  2017 median income  2017 median income margin of error  \
# 0  36001000100               27250                               10262
# 1  36001000200               24091                                6623
# 2  36001000300               33454                               15095
# 3  36001000401               74255                                7279
# 4  36001000403               70815                               10428
#
#    2017 race: total households  2017 race: total households margin of error  \
# 0                         1939                                          260
# 1                         4731                                          676
# 2                         5558                                          646
# 3                         2459                                          266
# 4                         4695                                          456
#
#    2017 race: White  2017 race: Black  2017 race: Asian  2017 race: Other  \
# 0               502              1142                16               112
# 1               710              3474               104                32
# 2              2589              1539               559               291
# 3              2183               131                92                28
# 4              3256               714               416                79
#
#    2017 race: 2 or more races
# 0                         167
# 1                         411
# 2                         580
# 3                          25
# 4                         230

# %% [markdown]
# ### 2. Group Stations by Geoid

# %%
#group by geoid and count number of stations
stations_geoid = stations.groupby(['geoid']).size().reset_index(name = 'Number of Stations')
stations_geoid = stations_geoid.sort_values('Number of Stations', ascending=False)
stations_geoid.head()
# Out:
#            geoid  Number of Stations
# 269  36061014300                  14
# 24   36047005300                   9
# 140  36061000700                   7
# 344  36081001900                   7
# 227  36061009900                   6

# %%
stations_geoid.loc[stations_geoid['geoid'] == 36047010000]
# Out:
# Empty DataFrame
# Columns: [geoid, Number of Stations]
# Index: []

# %%
stations['geoid'].nunique()
# Out:
# 382

# %%
stations_geoid['geoid'].nunique()
# Out:
# 382

# %%
plt.hist(stations_geoid['Number of Stations'], bins=10)
# Out:
# (array([266.,  61.,  30.,  21.,   2.,   0.,   1.,   0.,   0.,   1.]),
#  array([ 1. ,  2.3,  3.6,  4.9,  6.2,  7.5,  8.8, 10.1, 11.4, 12.7, 14. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Here we can see that there is a very uneven distribution of stations across geo ids.
# While some geoid's have 14 stations, a striking majority of geoids have 1 station.

# %%
stations_geoid['Number of Stations'].value_counts()
# Out:
# 1     145
# 2     121
# 3      61
# 4      30
# 5      14
# 6       7
# 7       2
# 14      1
# 9       1
# Name: Number of Stations, dtype: int64

# %%
#remove park geoids

geoids_remove=['36061014300','36047017700','36061000500','36081009900','36061031703','36047001800','36081003700']

stations_geoid = stations_geoid[~stations_geoid['geoid'].isin(geoids_remove)]
len(stations_geoid)
# Out:
# 375

# %%
plt.hist(stations_geoid['Number of Stations'], bins=10)
plt.title('All Stations by Geoids (excluding parks)')
plt.xlabel('Number of Stations')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
stations_geoid['Number of Stations'].unique()
# Out:
# array([9, 7, 6, 5, 4, 3, 2, 1])

# %%
stations_geoid['Number of Stations'].value_counts()
# Out:
# 1    144
# 2    118
# 3     61
# 4     29
# 5     13
# 6      7
# 7      2
# 9      1
# Name: Number of Stations, dtype: int64

# %% [markdown]
# Here we can see that there is a very uneven distribution of stations across geo ids.
# While some geoid's have 9 stations, a striking majority of geoids have 1 station.

# %% [markdown]
# Here, we can confirm and get a nummerical value of how the number of stations differ by geoid.
# A majority of the geoids have just 1 or 2 stations.
# However a few sect geoids hace 7, 9  stations.
#
# Overall, we can see a very uneven distribution of stations per geoid

# %% [markdown]
# ### 3. Race by Geoid

# %% [markdown]
# ## 2. Relationship between Trips and Stations

# %% [markdown]
# ### Add number of stations at each geoid

# %% [markdown]
# #### Start Station with Parks

# %%
## Number of Stations at each geoid
trips_start_df= pd.merge(stations_geoid,trips_start_df,  on=['geoid'], how='inner')
trips_start_df.head()
# Out:
#          geoid  Number of Stations  Number of Trips
# 0  36061014300                  14           257733
# 1  36047005300                   9            24112
# 2  36061000700                   7           161347
# 3  36081001900                   7            16798
# 4  36061009900                   6           230264

# %% [markdown]
# #### Start Station without Parks

# %%
## Number of Stations at each geoid
trips_start_df= pd.merge(stations_geoid,trips_start_df,  on=['geoid'], how='inner')
trips_start_df.head()
# Out:
#          geoid  Number of Stations  Number of Trips
# 0  36047005300                   9            24112
# 1  36061000700                   7           161347
# 2  36081001900                   7            16798
# 3  36061009900                   6           230264
# 4  36061008300                   6           181099

# %% [markdown]
# #### End Station

# %%
## Number of Stations at each geoid
trips_end_df= pd.merge(stations_geoid,trips_end_df,  on=['geoid'], how='inner')
trips_end_df.head()
# Out:
#          geoid  Number of Stations  Number of Trips
# 0  36061014300                  14           236408
# 1  36047005300                   9            26498
# 2  36061000700                   7           167929
# 3  36081001900                   7            17109
# 4  36061009900                   6           236628

# %% [markdown]
# #### End Station without Parks

# %%
## Number of Stations at each geoid
trips_end_df= pd.merge(stations_geoid,trips_end_df,  on=['geoid'], how='inner')
trips_end_df.head()
# Out:
#          geoid  Number of Stations  Number of Trips
# 0  36047005300                   9            26498
# 1  36061000700                   7           167929
# 2  36081001900                   7            17109
# 3  36061009900                   6           236628
# 4  36061008300                   6           183029

# %% [markdown]
# ## Plot number of stations by number of trips

# %% [markdown]
# ### Start Stations

# %%
## Your solution here
sns.relplot(x="Number of Stations", y="Number of Trips", data=trips_start_df)
plt.xlabel("Number of Stations")
plt.ylabel("Number of Trips")
plt.title("Number of Stations vs Number of Trips Scatterplot")
plt.show()

# %%
sns.lineplot(x="Number of Stations", y="Number of Trips", data=trips_start_df)
plt.xlabel("Number of Stations")
plt.ylabel("Number of Trips")
plt.title("Number of Stations vs Number of Trips Scatterplot")
plt.show()

# %% [markdown]
# ### Start Stations without Parks

# %%
## Your solution here
sns.relplot(x="Number of Stations", y="Number of Trips", data=trips_start_df)
plt.xlabel("Number of Stations")
plt.ylabel("Number of Trips")
plt.title("Number of Stations vs Number of Trips Scatterplot")
plt.show()

# %%
sns.lineplot(x="Number of Stations", y="Number of Trips", data=trips_start_df)
plt.xlabel("Number of Stations")
plt.ylabel("Number of Trips")
plt.title("Number of Stations vs Number of Trips Scatterplot")
plt.show()

# %% [markdown]
# ### End Stations with parks

# %%
## Your solution here
sns.relplot(x="Number of Stations", y="Number of Trips", data=trips_end_df)
plt.xlabel("Number of Stations")
plt.ylabel("Number of Trips")
plt.title("Number of Stations vs Number of Trips Scatterplot")
plt.show()

# %%
sns.lmplot(x="Number of Stations", y="Number of Trips",  data=trips_end_df)

# %%
sns.lineplot(x="Number of Stations", y="Number of Trips", data=trips_end_df)
plt.xlabel("Number of Stations")
plt.ylabel("Number of Trips")
plt.title("Number of Stations vs Number of Trips Scatterplot")
plt.show()

# %%
sns.scatterplot(x="Number of Trips", y="Number of Stations", data=trips_end_df)
plt.xlabel("Number of Trips")
plt.ylabel("Number of Stations")
plt.title("Number of Stations vs Number of Trips Scatterplot")
plt.show()

# %% [markdown]
# ### End Stations without parks

# %%
## Your solution here
sns.relplot(x="Number of Stations", y="Number of Trips", data=trips_end_df)
plt.xlabel("Number of Stations")
plt.ylabel("Number of Trips")
plt.title("Number of Stations vs Number of Trips Scatterplot")
plt.show()

# %%
sns.lmplot(x="Number of Stations", y="Number of Trips",  data=trips_end_df)

# %%
sns.lineplot(x="Number of Stations", y="Number of Trips", data=trips_end_df)
plt.xlabel("Number of Stations")
plt.ylabel("Number of Trips")
plt.title("Number of Stations vs Number of Trips Scatterplot")
plt.show()

# %% [markdown]
# From the two graphs of the relationship between number of stations and the number of trips, we can't conclude that more stations will necesscarily correlate with more trips.
#
#
# - not a linear relationship...
# - what can we use in this case?
#
# - no trips between 10-13
# - why are there 9 stations in a place with almost no trips at all...?
# - there is a very disproportionate place ment of the number of trips.
# - what could be the reason for this?

# %% [markdown]
# Overall, there doesn't seem to be a pattern with Trips and Stations.
# We should look further into each of the geoid's to see what characteristics each of the geoid's have.
# Though there is some sort of bell shaped curve, we can't conclude that stations are good predictors of the number of trips.
# Just because there are more trips doesn't mean that there are more stations in that area. Also just becuase there are more stations that doesn't mean that there are more trips in that area.
# Like we researched in different articles, what could be influencing the number of trips in a geodistrict area is not the amount of stations but other factors such as race and income differences across different geoids.
# People in less wealthier areas may be less likely to use public bikes due to concerns such as prices, safety , work commuting areas ...etc.
#
# Could there be sth else that is influencing number of trips? What characteristics does a geoid district have and can a certain race/income distribution of a geoid be a good predictor of the number of trips taken from that place?
#
# **Trips**
# -  Across different number of trips, is there a difference in race/income distribution?
# -  Is there a difference between geoids with more trips and geoids with less trips?
# - Can we observe a pattern btw trips and race/income by geoid?
#
# **Stations**
# - Across different number of stations, Is there a difference in race/income distribution?
# - Within a group of geoid with a certain num of stations (ex geoid with 1 station) what is the race/income distributionlike? What is the population like?

# %% [markdown]
# #### Importing the CSVs for Usage

# %%
st_df = pd.read_csv('../citibike-nyc/data/citibike_stations_geoid_final.csv')

# %%
race_df = pd.read_csv('../citibike-nyc/data/race_and_income_final.csv')

# %%
cmbnd = (race_df.set_index('geoid')).join((st_df.set_index('geoid')),how='inner')

# %%
cmbnd['geoid'] = cmbnd.index
cmbnd.reset_index(drop=True,inplace=True)

# %% [markdown]
# #### Creating a column with the number of stations

# %%
new_cmbnd =  cmbnd.groupby('geoid')[['station_id']].count()
new_cmbnd.rename(columns={'station_id':'num_stations'},inplace=True)
new_cmbnd.reset_index(inplace=True)

# %%
total_cmbnd = cmbnd.set_index('geoid').join(new_cmbnd.set_index('geoid'),how='inner')

# %%
total_cmbnd.reset_index()
total_cmbnd[:1]
total_cmbnd.shape
# Out:
# (801, 25)

# %% [markdown]
# ### By doing this, we're only looking at the geoids with stations

# %% [markdown]
# ## Normalizing the Data

# %%
total_cmbnd["white_p"] = total_cmbnd["2017 race: White"]/total_cmbnd["2017 race: total households"]
total_cmbnd["black_p"] = total_cmbnd["2017 race: Black"]/total_cmbnd["2017 race: total households"]
total_cmbnd["asian_p"] = total_cmbnd["2017 race: Asian"]/total_cmbnd["2017 race: total households"]
total_cmbnd["other_p"] = total_cmbnd["2017 race: Other"]/total_cmbnd["2017 race: total households"]
total_cmbnd["2_or_more"] = total_cmbnd["2017 race: 2 or more races"]/total_cmbnd["2017 race: total households"]

# %% [markdown]
# ## Multiplying the decimals by 100

# %%
total_cmbnd["white_p"] = total_cmbnd["white_p"] * 100
total_cmbnd["black_p"] = total_cmbnd["black_p"] * 100
total_cmbnd["asian_p"] = total_cmbnd["asian_p"] * 100
total_cmbnd["other_p"] = total_cmbnd["other_p"] * 100
total_cmbnd["2_or_more"] = total_cmbnd["2_or_more"] * 100

# %% [markdown]
# ## Classifying Census Tract as majority race group

# %%
total_cmbnd['majority_race'] = total_cmbnd[['white_p','black_p','asian_p','other_p','2_or_more']].idxmax(axis=1)

# %%
total_cmbnd['majority_race'].unique()
# Out:
# array(['white_p', 'black_p', 'other_p', 'asian_p'], dtype=object)

# %% [markdown]
# #### From this we can see that 2 or more races never make up the majority of one census tract, and that there are certain neighborhoods where one race does not make up the majority of the neighborhood

# %% [markdown]
# # Race vs Number of Stations

# %% [markdown]
# ### White Households

# %%
plt.scatter(x = total_cmbnd['num_stations'], y = total_cmbnd['white_p'], color = "red", s = 80, alpha= .3, label = "White") 
plt.xlabel("Number of Stations in Census Tract")
plt.ylabel("Percentage of White Race in Census Tract")
plt.title("The Number of Stations in Census Tract vs. Percentage of White Households ")
plt.legend()
plt.show()

# %% [markdown]
# ##### In this graph we can see that there at higher number of stations per census tract, there's a higher percentage of white households.

# %% [markdown]
# ### Black Households

# %%
plt.scatter(x = total_cmbnd['num_stations'], y = total_cmbnd['black_p'], color = "blue", s = 80, alpha = .3, label = "Black")
plt.xlabel("Number of Stations in Census Tract")
plt.ylabel("Percentage of Black Race in Census Tract")
plt.title("The Number of Stations in Census Tract vs. Percentage of Black HouseHolds ")
plt.legend()
plt.show()

# %% [markdown]
# #### From here we can see that at higher number of stations per census tract, there's a lower percentage of black households

# %%
plt.scatter(x = total_cmbnd['num_stations'], y = total_cmbnd['asian_p'], color = "green", s = 80, alpha = .3, label = "Asian")
plt.xlabel("Number of Stations in Census Tract")
plt.ylabel("Percentage of Asian Race in Census Tract")
plt.title("The Number of Stations in Census Tract vs. Percentage of Asian HouseHolds ")
plt.legend()
plt.show()

# %% [markdown]
# ##### From this graph we can see that Asian populations have a mainly low population. That being said, as shown with the data points on 7 number of stations, there's a higher percentage of asian households in census tracts with higher number of stations compared to black household percentages.

# %% [markdown]
# ## Number of Stations Based on Majority Race in Neighborhood

# %%
w_major = total_cmbnd[total_cmbnd['majority_race'] == 'white_p']
print("The average number of stations for majority white tracts is:", round(w_major.num_stations.mean(),2))
b_major = total_cmbnd[total_cmbnd['majority_race'] == 'black_p']
print("The average number of stations for majority black tracts is:", round(b_major.num_stations.mean(),2))
a_major = total_cmbnd[total_cmbnd['majority_race'] == 'asian_p']
print("The average numbre of stations for majority asian tracts is:", round(a_major.num_stations.mean(),2))
o_major = total_cmbnd[total_cmbnd['majority_race'] == 'other_p' ]
# Out:
# The average number of stations for majority white tracts is: 3.07
# The average number of stations for majority black tracts is: 2.14
# The average numbre of stations for majority asian tracts is: 2.92

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
y = ['Majority White', 'Majority Black', 'Majority Asian', 'Majority Other']
x = [w_major.num_stations.mean(), b_major.num_stations.mean(), a_major.num_stations.mean(), o_major.num_stations.mean()]
plt.bar(y,x)
plt.title('The Average Number of Stations by Majority Race')
plt.xlabel('Majority Race in Census Tract')
plt.ylabel('Average Number of Stations')
plt.show()

# %% [markdown]
# ##### From this we can see that majority asian and majority white neighborhoods have fairly similar average number of stations in their census tracts. On the other hand, majority black and other census tracts have lower average number of stations.

# %% [markdown]
# # Can the Percentage of Race predict whether the number of stations is Above the Median Number?

# %% [markdown]
# ## White Households Predicting Above Median Number of Stations

# %%
station_median = total_cmbnd['num_stations'].median()
station_median
# Out:
# 3.0

# %%
##creating a column that states whether number of station is above median or not
total_cmbnd['above_median_station'] = np.where(total_cmbnd['num_stations']>= station_median, True, False)

# %%
racevsstations_w = LogisticRegression().fit(total_cmbnd[['white_p']],total_cmbnd['above_median_station'])
predict_num_stations_w = racevsstations_w.predict(total_cmbnd[['white_p']])
#sns.barplot(x = 'white_percentage', y ='num_stations', data = total_cmbnd)
plt.scatter(x = total_cmbnd['white_p'], y = total_cmbnd['above_median_station'], c = "red", label = "Original Data")
plt.plot(total_cmbnd['white_p'],predict_num_stations_w, c = "green", label = "Prediction")
plt.xlabel("Percentage of White Households")
plt.ylabel("Probability")
plt.title("Probability of Percentage of White Households and Above or Equal to Median Number Stations")
plt.legend()
plt.show()

# %% [markdown]
# #### This graph shows that as the percentage of white households increases in the census tract, it's more likely that the number of the stations is above or equal to the median number of stations.

# %% [markdown]
# ### r^2 value, or how much of the data is explained by this variable

# %%
w_r_sqr = racevsstations_w.score(total_cmbnd[['white_p']],total_cmbnd['above_median_station'])
print('The r^2 value of percentage white race and number of stations', w_r_sqr)
# Out:
# The r^2 value of percentage white race and number of stations 0.5530586766541823

# %% [markdown]
# #### The r^2 value shows that white household percentage explains 55% of whether the number of stations is above the median number of stations.

# %% [markdown]
# ## Black Households Predicting Above Median Number of Stations

# %%
racevsstations_b = LogisticRegression().fit(total_cmbnd[['black_p']],total_cmbnd['above_median_station'])
predict_num_stations_b = racevsstations_b.predict(total_cmbnd[['black_p']])
plt.scatter(x = total_cmbnd['black_p'], y = total_cmbnd['above_median_station'], c = "blue", label = "Original Data")
plt.plot(total_cmbnd['black_p'],predict_num_stations_b, c = "red", label= "Prediction")
plt.legend()
plt.xlabel("Percentage of Black Households")
plt.ylabel("Probability")
plt.title("Probability of Percentage of Black Households and Above or Equal to Median Number Stations")
plt.show()

# %% [markdown]
# #### This graph shows that as the percentage of black households increase in a census tract, the probability of the number of stations being above or equal to the median number decreases to 0.

# %% [markdown]
# ### r^2 value, or how much of the data is explained by this variable

# %%
b_r_sqr = racevsstations_b.score(total_cmbnd[['black_p']],total_cmbnd['above_median_station'])
print('The r^2 value of percentage black race and number of stations', b_r_sqr)
# Out:
# The r^2 value of percentage black race and number of stations 0.5555555555555556

# %% [markdown]
# ##### The r^2 value shows a similar reasoning with the white households example. However, both show fairly low r^2 values.

# %% [markdown]
# ## **MultiLinear progression**

# %% [markdown]
# #### After seeing that Asian neighborhoods and White neighborhoods predict a similar number of stations, let's look at multi linear progression

# %% [markdown]
# ### Asian and White

# %%
num_stat_a_and_w = LinearRegression().fit(total_cmbnd[['white_p','asian_p']],total_cmbnd['num_stations'])
print('The r^2 value of a multi linear regression using race percentage to predict number of stations: ')
print(num_stat_a_and_w.score(total_cmbnd[['white_p','asian_p']],total_cmbnd['num_stations']))
# Out:
# The r^2 value of a multi linear regression using race percentage to predict number of stations:
# 0.024565700380785316

# %% [markdown]
# ##### Using white and asian percentages to predict number of stations still predicts less of the data compared to black neighborhood percentages

# %% [markdown]
# ### Black and other

# %%
num_stat_b_and_o = LinearRegression().fit(total_cmbnd[['black_p','other_p']],total_cmbnd['num_stations'])
print('The r^2 value of a multi linear regression using black and other race percentage to predict number of stations: ')
print(num_stat_a_and_w.score(total_cmbnd[['black_p','other_p']],total_cmbnd['num_stations']))
# Out:
# The r^2 value of a multi linear regression using black and other race percentage to predict number of stations:
# -0.20519487206700604

# %% [markdown]
# #### Black and the other race category are extremely poor for predicting the number of stations

# %% [markdown]
# #### **Using Income in Conjunction with Percentage of Households to Predict Above Median Stations**

# %%
median_income = total_cmbnd['2017 median income'].median()
median_income
# Out:
# 97135.0

# %%
##creating a column that states whether median income is above median or not
total_cmbnd['above_median_income'] = np.where(total_cmbnd['2017 median income']>= median_income, True, False)

# %% [markdown]
# #### Performing Multiple Linear Regression with Race

# %%
r_stations_w = LinearRegression().fit(total_cmbnd[['white_p', '2017 median income']],total_cmbnd['above_median_station'])
predict_num_stations_w = r_stations_w.predict(total_cmbnd[['white_p', 'above_median_income']])
print('The r^2 value of this model is', r_stations_w.score(total_cmbnd[['white_p', '2017 median income']],total_cmbnd['above_median_station']))
# Out:
# The r^2 value of this model is 0.026139443402503737

# %% [markdown]
# ##### Seeing as the score is so low, we will not use multiple linear regression to predict the probability of whether the census tract will have an above median number of stations

# %% [markdown]
# ## **What is the predicted number of stations in majority neighborhoods?**

# %% [markdown]
# ## Majority White Census Tracts

# %%
major_predict_stations = LinearRegression().fit(w_major[['white_p']], w_major['num_stations'])
predict_s_major_w = major_predict_stations.predict(w_major[['num_stations']])
print("The predicted average number of stations in majority white census tracts is : {:0.2f}".format(predict_s_major_w.mean()))
# Out:
# The predicted average number of stations in majority white census tracts is : 3.68

# %% [markdown]
# ##### When only looking at areas with majority white households, the predicted average number of stations is higher than the median

# %% [markdown]
# ## Majority Black Census Tracts

# %%
major_predict_stations_b = LinearRegression().fit(b_major[['black_p']], b_major['num_stations'])
predict_s_major_b = major_predict_stations_b.predict(b_major[['num_stations']])
print("The predicted average number of stations in majority black census tracts is : {:0.2f}".format(predict_s_major_b.mean()))
# Out:
# The predicted average number of stations in majority black census tracts is : 2.59

# %% [markdown]
# ##### Areas with majority black households have a lower predicted average number of stations.

# %% [markdown]
# ## **Highest Percentage of Race and Number of Stations**

# %%
temp_b_major = b_major.sort_values(by ='black_p', ascending= False)
temp_b_major = temp_b_major[:50]
temp_b_major.reset_index()
temp_w_major = w_major.sort_values(by ="white_p", ascending = False)
temp_w_major = temp_w_major[:50]
temp_w_major.reset_index()
temp_w_major[:0]
# Out:
# Empty DataFrame
# Columns: [station_id, station_name, lat, lon, first_trip, last_trip, rides, 2017 median income, 2017 median income margin of error, 2017 race: total households, 2017 race: total households margin of error, 2017 race: White, 2017 race: Black, 2017 race: Asian, 2017 race: Other, 2017 race: 2 or more races, num_stations, white_p, black_p, asian_p, other_p, 2_or_more, majority_race, above_median_station]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# ### Station Numbers for top 50 Highest Race Percentage Areas

# %%
plt.plot(temp_b_major['black_p'], temp_b_major['num_stations'], label = "Number of Stations")
plt.legend()
plt.xlabel("The Percentage of Black Households")
plt.ylabel("The Number of Stations")
plt.title("Top 50 Highest Black Percentage Geoids and Number of Stations")
plt.show()

# %%
plt.plot(temp_w_major['white_p'], temp_w_major['num_stations'], label ="Number of Stations")
plt.legend()
plt.xlabel("The Percentage of White Households")
plt.ylabel("The Number of Stations")
plt.title("Top 50 Highest White Percentage Geoids and Number of Stations")
plt.show()

# %% [markdown]
# #### From this graph, we can see that areas with high white percentages had higher peaks of number of stations when compared to areas with high black percentages.

# %% [markdown]
# # Income and Number of Stations

# %% [markdown]
# ## Can Income Predict Number of Stations?

# %%
income_stations = LogisticRegression().fit(total_cmbnd[['2017 median income']],total_cmbnd['above_median_station'])
income_predict_stations= income_stations.predict(total_cmbnd[['2017 median income']])
plt.scatter(x = total_cmbnd['2017 median income'], y = total_cmbnd['above_median_station'], c = "red", label = "Original Data")
plt.plot(total_cmbnd['2017 median income'],predict_num_stations_b, c = "black", label= "Prediction")
plt.legend()
plt.xlabel("2017 median Income")
plt.ylabel("Probability")
plt.title("Probability of Income and Above or Equal to Median Number Stations")
plt.show()

# %% [markdown]
# #### This graph shows that as the median income increases the probability of the census tract having an equal or higher number of stations increases as well.

# %%
print('Predicting income vs stations:',income_stations.score(total_cmbnd[['2017 median income']],total_cmbnd['above_median_station']))
# Out:
# Predicting income vs stations: 0.5280898876404494

# %% [markdown]
# ### Station Numbers for top 50 Highest Income Areas

# %%
temp_top_income = total_cmbnd.sort_values(by ='2017 median income', ascending= False)
temp_top_income = temp_top_income[:50]
temp_top_income.reset_index()
temp_top_income[:1]
temp_top_income.shape
# Out:
# (50, 25)

# %%
plt.plot(temp_top_income['2017 median income']/1000, temp_top_income['num_stations'], label ="Number of Stations")
plt.legend()
plt.xlabel("Median Income (thousands)")
plt.ylabel("The Number of Stations")
plt.title("Top 50 Highest Median Income Geoids and Number of Stations")
plt.show()

# %% [markdown]
# ##### This graph shows that geoids with high median incomes have fairly high numbers of stations.

# %% [markdown]
# ### Station Numbers for lowest 50 Income Areas

# %%
temp_bottom_income = total_cmbnd.sort_values(by ='2017 median income')
temp_bottom_income = temp_bottom_income[:50]
temp_bottom_income.reset_index()
temp_bottom_income.shape
total_cmbnd.shape
# Out:
# (801, 25)

# %%
plt.plot(temp_bottom_income['2017 median income']/1000, temp_bottom_income['num_stations'], label ="Number of Stations")
plt.legend()
plt.xlabel("Median Income (thousands)")
plt.ylabel("The Number of Stations")
plt.title("50 Lowest Income Geoids and Number of Stations")
plt.show()

# %% [markdown]
# ##### From this graphs we can infer that as income increases from a certain income level, the number of stations increases

# %% [markdown]
# ### Station Numbers for 50 middle Income Areas

# %%
temp_middle_income= total_cmbnd.sort_values(by ='2017 median income')
temp_middle_income = temp_middle_income[375:425]
temp_middle_income.reset_index()
temp_middle_income[:1]
# Out:
#              station_id     station_name        lat        lon  first_trip  \
# geoid
# 36061015400      3286.0  E 89 St & 3 Ave  40.780628 -73.952167  2016-08-02
#
#               last_trip  rides  2017 median income  \
# geoid
# 36061015400  2019-07-31  45413               93078
#
#              2017 median income margin of error  2017 race: total households  \
# geoid
# 36061015400                               17352                        15218
#
#              ...  2017 race: 2 or more races  num_stations    white_p  \
# geoid        ...
# 36061015400  ...                        1163             4  75.062426
#
#               black_p   asian_p   other_p  2_or_more  majority_race  \
# geoid
# 36061015400  5.565777  9.442765  2.286766   7.642266        white_p
#
#              above_median_station  above_median_income
# geoid
# 36061015400                  True                False
#
# [1 rows x 25 columns]

# %%
plt.plot(temp_middle_income['2017 median income']/1000, temp_middle_income['num_stations'], label ="Number of Stations")
plt.legend()
plt.xlabel("Median Income (thousands)")
plt.ylabel("The Number of Stations")
plt.title("50 Middle Income Geoids and Number of Stations")
plt.show()

# %% [markdown]
# ##### There seems to be high number of stations at a middle income. As the income increases, the number of stations decrease.

# %% [markdown]
# # Both Income and Race

# %% [markdown]
# ## Color Gradient of Race and Income

# %%
# a few columns of interest
cols = ['num_stations', 'white_p', 'black_p', 'asian_p', 'other_p', '2_or_more', '2017 median income']

# correlations (w/ color coding)
total_cmbnd[cols].corr().style.background_gradient(
    cmap='RdYlGn', 
    axis=None, 
    vmin=-0.8, 
    vmax=0.8
)
# Out:
# <style  type="text/css" >
# #T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row0_col0,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row1_col1,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row2_col2,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row3_col3,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row4_col4,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row5_col5,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row6_col6{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row0_col1,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row1_col0,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row4_col5,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row5_col4{
#             background-color:  #e2f397;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row0_col2,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row2_col0{
#             background-color:  #fedc88;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row0_col3,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row3_col0{
#             background-color:  #eef8a8;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row0_col4,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row4_col0{
#             background-color:  #fff3ac;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row0_col5,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row5_col0{
#             background-color:  #e6f59d;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row0_col6,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row6_col0{
#             background-color:  #cfeb85;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row1_col2,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row2_col1{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row1_col3,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row3_col1{
#             background-color:  #feca79;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row1_col4,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row4_col1{
#             background-color:  #eb5a3a;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row1_col5,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row5_col1{
#             background-color:  #fee491;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row1_col6,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row6_col1{
#             background-color:  #108647;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row2_col3,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row3_col2{
#             background-color:  #fdbf6f;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row2_col4,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row4_col2{
#             background-color:  #bbe278;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row2_col5,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row5_col2{
#             background-color:  #f7fcb4;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row2_col6,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row6_col2{
#             background-color:  #e75337;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row3_col4,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row4_col3{
#             background-color:  #fee08b;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row3_col5,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row5_col3{
#             background-color:  #fff0a6;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row3_col6,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row6_col3{
#             background-color:  #fffcba;
#             color:  #000000;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row4_col6,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row6_col4{
#             background-color:  #de402e;
#             color:  #f1f1f1;
#         }#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row5_col6,#T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row6_col5{
#             background-color:  #fff5ae;
#             color:  #000000;
#         }</style><table id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >num_stations</th>        <th class="col_heading level0 col1" >white_p</th>        <th class="col_heading level0 col2" >black_p</th>        <th class="col_heading level0 col3" >asian_p</th>        <th class="col_heading level0 col4" >other_p</th>        <th class="col_heading level0 col5" >2_or_more</th>        <th class="col_heading level0 col6" >2017 median income</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74level0_row0" class="row_heading level0 row0" >num_stations</th>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row0_col1" class="data row0 col1" >0.119827</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row0_col2" class="data row0 col2" >-0.172581</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row0_col3" class="data row0 col3" >0.070996</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row0_col4" class="data row0 col4" >-0.059902</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row0_col5" class="data row0 col5" >0.100789</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row0_col6" class="data row0 col6" >0.193542</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74level0_row1" class="row_heading level0 row1" >white_p</th>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row1_col0" class="data row1 col0" >0.119827</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row1_col2" class="data row1 col2" >-0.796163</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row1_col3" class="data row1 col3" >-0.228367</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row1_col4" class="data row1 col4" >-0.528877</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row1_col5" class="data row1 col5" >-0.138974</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row1_col6" class="data row1 col6" >0.698471</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74level0_row2" class="row_heading level0 row2" >black_p</th>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row2_col0" class="data row2 col0" >-0.172581</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row2_col1" class="data row2 col1" >-0.796163</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row2_col3" class="data row2 col3" >-0.267167</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row2_col4" class="data row2 col4" >0.256016</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row2_col5" class="data row2 col5" >0.037290</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row2_col6" class="data row2 col6" >-0.545877</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74level0_row3" class="row_heading level0 row3" >asian_p</th>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row3_col0" class="data row3 col0" >0.070996</td>
#                         <td id="T_fd3d1fc8_a0e0_11eb_a392_60f81db29d74row3_col1" cl

# %% [markdown]
# ##### From this figure we can see that majority black and other census tracts have a negative relationship with number of stations. On the other hand, majority white and asian census tracts have a slightly positive relationship. Also, median income has a positive relationship with number of stations as well. This indicates as white, asian, and median income increases, so does number of stations

# %% [markdown]
# ## Income Statistics based on majority race in Census Tract

# %%
## Mean of median income based on race
w_major = total_cmbnd[total_cmbnd['majority_race'] == 'white_p']
print("The mean of median income in majority white tracts is: ")
print(round(w_major['2017 median income'].mean(),1))

b_major = total_cmbnd[total_cmbnd['majority_race'] == 'black_p']
print("The mean of median income in majority black tracts is: ")
print(round(b_major['2017 median income'].mean(),1))

a_major = total_cmbnd[total_cmbnd['majority_race'] == 'asian_p']
print("The mean of median income in majority asian tracts is: ")
print(round(a_major['2017 median income'].mean(),1))
# Out:
# The mean of median income in majority white tracts is:
# 107220.5
# The mean of median income in majority black tracts is:
# 45790.3
# The mean of median income in majority asian tracts is:
# 60136.8

# %% [markdown]
# #### The mean of median income for the majority race census tracts show that majority white areas have a much higher average median income compared to majority black and majority asian tracts

# %% [markdown]
# ### Now that we see a consistent pattern that white majority census tracts and higher income census tracts have a higher number of stations, we can ask whether the current number of stations is meeting the needs of other geoids through trip data.

# %% [markdown]
# - First need to make connection between trips and demonstrating need.
#     - Correlation between number of stations and trips taken
#         - Perhaps using time to infer when someone might be using the bikes for work or something else?
#     - Look at geoids with lowest number of trips and number of stations
#     - Look at racial distribution of areas with lowest/highest number of trips

# %% [markdown]
# ## Evaluation of Significance

# %% [markdown]
# ## Interpretation and Conclusion

# %% [markdown]
# ## Limitations

# %% [markdown]
# ### Overall Limitations
#
# - We acknowledge that race and income are not the only factors that contribute to the distribution of citibike stations around NYC. We are trying to see if there is a correlations for race and income with the distribution of citibike stations.
#
# - Since our data is based off of citibikes in 2017, our results are limited to that year only. That being said, they may be an indicator of how citibike stations are distributed for other years as well.

# %% [markdown]
# ### Citi Bike Trip Data Limitations
#
# - The trip data **only includes the 'Subscribers' of the users**. Though there may be some one-time-customer passes from NYC residents, due to the large amount of data we decided to settle on subscribers only because there was a higher chance that these people were actually new york city residents. So our data may not be representative of other NYC residents that may have only used one-time passes.
#
# - We dropped rows where start station = end station. When the start station = end station we assumed that there would probably we a majority of cases where people where having trouble with using citibike in the inital process. However, **there may be cases where people would have been able to make complete round trips and returned them back to the same location in for some of the trips where the start station = end station**

# %% [markdown]
# ### Citi Bike Stations Data Limitations
#
# - One possible limitation of this station data set is that the **count of the number of trips taken from a station is actually the count up to the end of 2019, whereas our project focuses on 2017**. However, there is a workaround for this problem since we also have the trip data, we can just recalculate the number of trips taken from each station up to the end of 2017.
#
# - Another limitation is that **the station start date is not actually the date the station was added to the network but is instead the date at which the first trip was taken from the station**, which might not always be the same.

# %% [markdown]
# ### Race and Income Data Limitations

# %% [markdown]
# - One possible limitation of this data set is that **it only looks at survey data from 2017**. However, this is also consistent with the current data available on the American Community Survey website. Currently, the survey website data is only updated up until 2017. Because of this limitation, there may not be potential inaccuracies with representation in the data.
#
# - Moreover, populations like the homeless or digital nomads may not be recorded in the data. That being said, the survey itself was collected using this method in order to avoid bias in the data.

# %% [markdown]
# ## Source Code

# %% [markdown]
# ## Acknowledgements

# %% [markdown]
# ## Questions for Reviewers

# %% [markdown]
# ## Appendix
#
# **updated version of data cleaning links**
